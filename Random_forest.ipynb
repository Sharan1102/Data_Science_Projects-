# %% [markdown]
# <a href="https://colab.research.google.com/github/Sharan1102/Data_Science_Projects-/blob/main/Random_forest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv("https://raw.githubusercontent.com/neo-stark-team/Datasets/main/smartwatch.csv")
df
# Out:
#       Unnamed: 0    X1  age  gender  height  weight      steps  hear_rate  \
# 0              1     1   20       1   168.0    65.4  10.771429  78.531302
# 1              2     2   20       1   168.0    65.4  11.475325  78.453390
# 2              3     3   20       1   168.0    65.4  12.179221  78.540825
# 3              4     4   20       1   168.0    65.4  12.883117  78.628260
# 4              5     5   20       1   168.0    65.4  13.587013  78.715695
# ...          ...   ...  ...     ...     ...     ...        ...        ...
# 6259        6260  3666   46       0   157.5    71.4   1.000000  35.000000
# 6260        6261  3667   46       0   157.5    71.4   1.000000  35.000000
# 6261        6262  3668   46       0   157.5    71.4   1.000000  35.000000
# 6262        6263  3669   46       0   157.5    71.4   1.000000  35.000000
# 6263        6264  3670   46       0   157.5    71.4   1.000000  35.000000
#
#        calories  distance  entropy_heart  entropy_setps  resting_heart  \
# ...

# %%
df.drop("Unnamed: 0",axis=1,inplace=True)
df
# Out:
#         X1  age  gender  height  weight      steps  hear_rate   calories  \
# 0        1   20       1   168.0    65.4  10.771429  78.531302   0.344533
# 1        2   20       1   168.0    65.4  11.475325  78.453390   3.287625
# 2        3   20       1   168.0    65.4  12.179221  78.540825   9.484000
# 3        4   20       1   168.0    65.4  12.883117  78.628260  10.154556
# 4        5   20       1   168.0    65.4  13.587013  78.715695  10.825111
# ...    ...  ...     ...     ...     ...        ...        ...        ...
# 6259  3666   46       0   157.5    71.4   1.000000  35.000000  20.500000
# 6260  3667   46       0   157.5    71.4   1.000000  35.000000  20.500000
# 6261  3668   46       0   157.5    71.4   1.000000  35.000000  20.500000
# 6262  3669   46       0   157.5    71.4   1.000000  35.000000  20.500000
# 6263  3670   46       0   157.5    71.4   1.000000  35.000000  20.500000
#
#       distance  entropy_heart  entropy_setps  resting_heart  corr_heart_steps  \
# ...

# %%
df.drop_duplicates()
# Out:
#         X1  age  gender  height  weight      steps  hear_rate   calories  \
# 0        1   20       1   168.0    65.4  10.771429  78.531302   0.344533
# 1        2   20       1   168.0    65.4  11.475325  78.453390   3.287625
# 2        3   20       1   168.0    65.4  12.179221  78.540825   9.484000
# 3        4   20       1   168.0    65.4  12.883117  78.628260  10.154556
# 4        5   20       1   168.0    65.4  13.587013  78.715695  10.825111
# ...    ...  ...     ...     ...     ...        ...        ...        ...
# 6259  3666   46       0   157.5    71.4   1.000000  35.000000  20.500000
# 6260  3667   46       0   157.5    71.4   1.000000  35.000000  20.500000
# 6261  3668   46       0   157.5    71.4   1.000000  35.000000  20.500000
# 6262  3669   46       0   157.5    71.4   1.000000  35.000000  20.500000
# 6263  3670   46       0   157.5    71.4   1.000000  35.000000  20.500000
#
#       distance  entropy_heart  entropy_setps  resting_heart  corr_heart_steps  \
# ...

# %%
df.isnull().sum()
# Out:
# X1                      0
# age                     0
# gender                  0
# height                  0
# weight                  0
# steps                   0
# hear_rate               0
# calories                0
# distance                0
# entropy_heart           0
# entropy_setps           0
# resting_heart           0
# corr_heart_steps        0
# norm_heart              0
# intensity_karvonen      0
# sd_norm_heart           0
# steps_times_distance    0
# device                  0
# activity                0
# dtype: int64

# %%
from sklearn import preprocessing

for col in df.select_dtypes(include=['object']).columns:
 label_encoder=preprocessing.LabelEncoder()
  #fit the encoder
 label_encoder.fit(df[col].unique())
  #transform the column
 df[col]=label_encoder.transform(df[col])
  #print the column name and }") the unique encoded values
 print(f"{col}: {df[col].unique()}")
# Out:
# device: [0 1]
# activity: [0 5 4 1 2 3]

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
df.drop("intensity_karvonen",axis=1,inplace=True)
df
# Out:
#         X1  age  gender  height  weight      steps  hear_rate   calories  \
# 0        1   20       1   168.0    65.4  10.771429  78.531302   0.344533
# 1        2   20       1   168.0    65.4  11.475325  78.453390   3.287625
# 2        3   20       1   168.0    65.4  12.179221  78.540825   9.484000
# 3        4   20       1   168.0    65.4  12.883117  78.628260  10.154556
# 4        5   20       1   168.0    65.4  13.587013  78.715695  10.825111
# ...    ...  ...     ...     ...     ...        ...        ...        ...
# 6259  3666   46       0   157.5    71.4   1.000000  35.000000  20.500000
# 6260  3667   46       0   157.5    71.4   1.000000  35.000000  20.500000
# 6261  3668   46       0   157.5    71.4   1.000000  35.000000  20.500000
# 6262  3669   46       0   157.5    71.4   1.000000  35.000000  20.500000
# 6263  3670   46       0   157.5    71.4   1.000000  35.000000  20.500000
#
#       distance  entropy_heart  entropy_setps  resting_heart  corr_heart_steps  \
# ...

# %%
x= df.drop(["activity","device"],axis=1)
y =df["activity"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
clf_dt=DecisionTreeClassifier()
clf_dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_predict=clf_dt.predict(x_test)
y_predict
# Out:
# array([5, 1, 2, ..., 2, 3, 5])

# %%
accuracy_dt=accuracy_score(y_predict,y_test)
print("Decision Tree Accuracy:",accuracy_dt)
# Out:
# Decision Tree Accuracy: 0.7924980047885076

# %%
from sklearn.ensemble import RandomForestClassifier
random_forest=RandomForestClassifier()  #RandomForestClassifier(n_estimators=150,max_depth=)
random_forest.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_predict_rf=random_forest.predict(x_test)
y_predict_rf
# Out:
# array([5, 1, 2, ..., 2, 3, 5])

# %%
accuracy_dt=accuracy_score(y_predict_rf,y_test)
print("Decision Tree Accuracy:",accuracy_dt)
# Out:
# Decision Tree Accuracy: 0.8866719872306464
